# %%
import requests
from bs4 import BeautifulSoup as bs
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.262 Safari/537.36'}

#請在這裡輸入正妹抱抱的網址
res = requests.get('http://ck101.com/forum-1345-3.html',headers = headers)
#print res
soup = bs(res.text)
#在資料夾存一個正妹抱抱的期別連結
f =  open('ck101-2.txt','w')
for link in soup.select('h3'):
    for a in link.select('a'):
        f.write(a.attrs['href']+'\n')
f.close()

# %%
import requests
from bs4 import BeautifulSoup as bs
import shutil
import os
#
f = open('ck101-2.txt','r')
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.262 Safari/537.36'}

for line in f:
    url = line
    res = requests.get(url,headers = headers)
    print res
    soup = bs(res.text)
    for title in soup.select('h1'):
        dirname = title.text
        if os.path.isdir(dirname)==False:
            os.mkdir(dirname)    
            for entry in soup.select('.t_f'):
                url_format = '1'
                for link in entry.select('a')[0:-2]:
                    url_next = link.attrs['href']
                    if url_next != url_format:
                        url_format = url_next
                        print url_next
                        res2 = requests.get(url_next,headers = headers) 
                        soup2 = bs(res2.text)
                        for link in soup2.select('.t_f'):
                            for em in link.select('img')[2:]:
                                try:
                                    fname = em.get('file').split('/')[-1]  
                                    extension = fname.split('.')[1]
                                except:
                                    break
                                try:
                                    if 'jpg' in em.get('file'):
                                        print fname
                                        response = requests.get(em.get('file'), headers = headers, stream=True)
                                        with open(dirname+ '/' +fname, 'wb') as out_file:
                                            shutil.copyfileobj(response.raw, out_file)
                                        del response
                                except:
                                    break
        else:
            break
# Out:
# <Response [200]>
# http://ck101.com/thread-3346608-1-1.html
# LHpFV99.jpg
# bWHPT1Y.jpg
# zyvwKGR.jpg
# REKoWxF.jpg
# http://ck101.com/thread-3346890-1-1.html
# Ksotc8Q.jpg
# Zoy5RgKt.jpg
# g1nY8JRt.jpg
# r42xwyKt.jpg
# jO47CEit.jpg
# ULx5El3t.jpg
# WJ6jtg0.jpg
# O2H6aQYt.jpg
# aBi6dert.jpg
# wWcUf8Wt.jpg
# 6uUPVBUt.jpg
# QjKYChet.jpg
# http://ck101.com/thread-3346496-1-1.html
# ZtGF7IR.jpg
# XxLUXcy.jpg
# v95KXWO.jpg
# LvFxjKlt.jpg
# SqOzmT5t.jpg
# http://ck101.com/thread-3347045-1-1.html
# 4g1g1J2t.jpg
# Zq4kA0t.jpg
# E29xDCj.jpg
# bG9GdPut.jpg
# Zz0X9cdt.jpg
# Heg0b2W.jpg
# nyQUgoKt.jpg
# 6PcBIt4.jpg
# CuLObR1t.jpg
# rHFBkjWt.jpg
# mmz8tzW.jpg
# qsU32vi.jpg
# PwHvjBxt.jpg
# LfAYoVD.jpg
# GbjHHIq.jpg
# 6B2jTvm.jpg
# HaPUXJnt.jpg
# GQ4R09pt.jpg
# PpUSVHd.jpg
# 7FnXNTz.jpg
# LS5H5JZ.jpg
# http://ck101.com/thread-3346970-1-1.html
# iRPEC1Ht.jpg
# J0pFjsqt.jpg
# xHtV2rXt.jpg
# qGiU0wet.jpg
# B6iNacgt.jpg
# ofxAIZdt.jpg
# tyrEiTjt.jpg
# Mqht1VXt.jpg
# 8GIP7GKt.jpg
# jQ5HOgbt.jpg
# bzibkkAt.jpg
# Vz4ntMQt.jpg
# DxqdrN3t.jpg
# TOsiMyLt.jpg
# qmwQUtst.jpg
# BxXbC6yt.jpg
# BTscuvgt.jpg
# qYpOwR5t.jpg
# fJwaOout.jpg
# ZyETPVwt.jpg
# osfLETWt.jpg
# xw8EyEZt.jpg
# Nmc9uixt.jpg
# eRinyett.jpg
# qvs62Aet.jpg
# Rpdxrqct.jpg
# SRLKFKpt.jpg
# PiPVjggt.jpg
# nfaLhUZt.jpg
# q1i11aBt.jpg
# qfUynT2t.jpg
# vaH13Tyt.jpg
# fcW11Lct.jpg
# aRaxAjut.jpg
# NTDJpsjt.jpg
# F8Lk1aht.jpg
# 2EBtZzct.jpg
# ua8D5BNt.jpg

# %% [markdown]
# ##試試markdown
